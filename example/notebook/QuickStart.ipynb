# %% [markdown]
# # AdelWheat quickstart

# %% [markdown]
# # Create a canopy

# %%
from openalea.adel.astk_interface import AdelWheat

# instantiate adel for two plants arraged on a line
adel = AdelWheat(nplants=2, aspect='line')

# generate a wheat canopy 300 degree.day after emergence 
g = adel.setup_canopy(300)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R callback write-console: De plus :
# WARNING:rpy2.rinterface_lib.callbacks:R callback write-console: Messages d'avis :
#
# WARNING:rpy2.rinterface_lib.callbacks:R callback write-console: 1: NAs introduits lors de la conversion automatique
#
# WARNING:rpy2.rinterface_lib.callbacks:R callback write-console: 2: NAs introduits lors de la conversion automatique

# %% [markdown]
# # Display

# %%
# view the mtg content at scale 1
g.display(max_scale=1)
# Out:
# MTG : nb_vertices=145, nb_scales=6
# /plant1			(id=1)
# /plant2			(id=72)

# %%
# %gui qt
# Out:
# QApplication: invalid style override 'kvantum' passed, ignoring it.
# 	Available styles: Windows, Fusion

# %%
# display the 3D generated scene
adel.plot(g)

# %%
import warnings
warnings.warn('test', DeprecationWarning)
# Out:
# c:\python27\lib\site-packages\ipykernel\__main__.py:2: DeprecationWarning: test
#   from ipykernel import kernelapp as app
